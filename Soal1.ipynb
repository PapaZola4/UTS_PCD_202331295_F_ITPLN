# %% [markdown]
# ### Import Library

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %% [markdown]
# ### Membaca Gambar

# %%
img = cv2.imread('namaku.png')

# %%
img.shape
# Out:
# (960, 1280, 3)

# %%
[baris, kolom] = img.shape[:2]

# %% [markdown]
# ### Convert BGR to RGB

# %%
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### Deteksi Warna

# %%
image_path = "namaku.png"  
img = Image.open(image_path).convert("RGB")
rgb = np.array(img)

red_channel = rgb[:, :, 0]   
green_channel = rgb[:, :, 1]  
blue_channel = rgb[:, :, 2]   

fig, axs = plt.subplots(4, 2, figsize=(10, 8))

axs[0, 0].imshow(rgb)
axs[0, 0].set_title("CITRA ASLI")
axs[0,1].hist(rgb.ravel(), 256, [0,256])

axs[1, 0].imshow(red_channel, cmap='gray')
axs[1,0].set_title("MERAH")
axs[1,1].hist(red_channel.ravel(), 256, [0,256])

axs[2, 0].imshow(green_channel, cmap='gray')
axs[2, 0].set_title("HIJAU")
axs[2,1].hist(green_channel.ravel(), 256, [0,256])

# Channel Biru (Grayscale)
axs[3, 0].imshow(blue_channel, cmap='gray')
axs[3, 0].set_title("BIRU")
axs[3,1].hist(blue_channel.ravel(), 256, [0,256])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10160\827282113.py:13: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[0,1].hist(rgb.ravel(), 256, [0,256])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10160\827282113.py:17: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[1,1].hist(red_channel.ravel(), 256, [0,256])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10160\827282113.py:21: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[2,1].hist(green_channel.ravel(), 256, [0,256])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10160\827282113.py:26: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[3,1].hist(blue_channel.ravel(), 256, [0,256])
